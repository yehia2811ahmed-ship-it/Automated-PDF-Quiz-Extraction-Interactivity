# %%
from google.colab import files

# رفع الملف
uploaded = files.upload()

# الحصول على اسم الملف المرفوع
file_name = list(uploaded.keys())[0]
print(f"تم رفع الملف بنجاح: {file_name}")
# Out:
#      <input type="file" id="files-ceb993cf-a2f9-491c-b3b9-51aaa61ea8ad" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ceb993cf-a2f9-491c-b3b9-51aaa61ea8ad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pdfplumber
import re

file_path = "700 question .pdf"
output_filename = "clean_final_questions.txt"

def extract_to_final_lines(pdf_path):
    with pdfplumber.open(pdf_path) as pdf, open(output_filename, "w", encoding="utf-8") as f:
        for page in pdf.pages:
            table = page.extract_table()
            if not table: continue

            for row in table:
                # التحقق من وجود بيانات في الصف
                if row[0] and row[1]:
                    # 1. استخراج الرقم والسؤال وتنظيفهم من أي أقواس أو أسطر
                    q_num = str(row[0]).strip()
                    q_text = " ".join(str(row[1]).split())

                    # 2. استخراج الخيارات ودمجها في سطر واحد
                    options_raw = " ".join([str(item) for item in row[2:] if item])
                    options_clean = " ".join(options_raw.split())

                    # 3. تطبيق التنسيق: a- answer.
                    formatted_opt = re.sub(r'([a-d])\.\s*', r'\1- ', options_clean)
                    formatted_opt = re.sub(r'\s+([b-d]-)', r'. \1', formatted_opt)
                    if formatted_opt and not formatted_opt.endswith('.'):
                        formatted_opt += "."

                    # 4. الكتابة النهائية (سؤال في سطر، إجابات في سطر)
                    full_q = f"{q_num}- {q_text}"
                    f.write(f"{full_q}\n")
                    f.write(f"{formatted_opt}\n")

                    # الطباعة في كولاب للتأكد
                    print(full_q)
                    print(formatted_opt)

# تشغيل الكود
extract_to_final_lines(file_path)
# Out:
# no- question
# answer.
# 1- the visibility is very bad here ; I can’t ….. Anything
# a- warn. b- hear. c- see. d- reach.
# 2- they are listening to the ………..
# a- radio. b- time. c- TV. d- map.
# 3- your TV is too………..
# a- louder. b- loud. c- loudest. d- loudly.
# 4- she speaks very ………..
# a- more quick. b- quickly. c- quicker. d- more quickly.
# 5- check your work………..
# a- more careful. b- more carefulness. c- careful. d- carefully.
# 6- you should report to the army………... ASAP
# a- headquarters. b- auditorium. c- piers. d- council.
# 7- Americans regard the half-dollar as a………..
# a- treasure. b- bad omen. c- taboo. d- good luck.
# 8- A:"I really need to speak to you now. "B:"oh,all right if you……
# a- complicate. b- resist. c- finalize. d- insist.
# 9- several soldiers were wounded during the battle.they were………..
# a- sad. b- caught. c- happy. d- hurt.
# 10- Joe is too skinny.He is ………..
# a- overweight. b- chubby. c- loud. d- underweight.
# ...

# %%
from google.colab import files
uploaded = files.upload()
ans_file_name = list(uploaded.keys())[0]
print(f"تم رفع ملف الإجابات بنجاح: {ans_file_name}")
# Out:
#      <input type="file" id="files-27563b80-0269-4e0a-9e08-9190aab6f3d4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-27563b80-0269-4e0a-9e08-9190aab6f3d4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pdfplumber
import re

# اسم الملف كما ظهر في رفعه
ans_file_path = "700 question answer.pdf"
output_filename = "vertical_answer_key.txt"

def extract_answers_fixed(pdf_path):
    all_lines = []
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            table = page.extract_table()
            if not table:
                continue

            for row in table:
                # تنظيف الصف من القيم الفارغة
                clean_row = [str(item).strip() for item in row if item]

                if len(clean_row) >= 2:
                    q_no = clean_row[0]
                    ans_char = clean_row[1]

                    # التأكد أن الأول رقم والثاني حرف واحد (a, b, c, d)
                    if q_no.isdigit() and len(ans_char) == 1 and ans_char.lower() in ['a', 'b', 'c', 'd']:
                        line = f"{q_no}- {ans_char.lower()}."
                        all_lines.append(line)
                        print(line)

    # كتابة النتائج في الملف
    if all_lines:
        with open(output_filename, "w", encoding="utf-8") as f:
            f.write("\n".join(all_lines))
        print(f"\n✅ نجحنا! تم استخراج {len(all_lines)} إجابة في ملف: {output_filename}")
    else:
        print("\n❌ لم يتم العثور على بيانات، تأكد من اسم الملف أو جرب كوداً آخر.")

# تشغيل الكود
extract_answers_fixed(ans_file_path)
# Out:
# 1- c.
# 2- a.
# 3- b.
# 4- b.
# 5- d.
# 6- a.
# 7- b.
# 8- d.
# 9- d.
# 10- d.
# 11- c.
# 12- c.
# 13- b.
# 14- d.
# 15- c.
# 16- a.
# 17- b.
# 18- c.
# 19- a.
# 20- c.
# 21- c.
# 22- b.
# 23- a.
# 24- c.
# 25- d.
# 26- a.
# 27- c.
# 28- b.
# 29- b.
# 30- a.
# 31- b.
# 32- d.
# 33- b.
# 34- a.
# 35- a.
# 36- c.
# 37- d.
# 38- b.
# 39- d.
# 40- b.
# 41- b.
# 42- a.
# 43- d.
# 44- c.
# 45- b.
# 46- c.
# 47- c.
# 48- d.
# 49- d.
# 50- d.
# 51- b.
# 52- c.
# 53- a.
# 54- a.
# 55- d.
# 56- c.
# 57- a.
# 58- d.
# 59- a.
# 60- b.
# 61- d.
# 62- b.
# 63- b.
# 64- b.
# 65- b.
# 66- c.
# 67- b.
# 68- d.
# 69- c.
# 70- b.
# 71- a.
# 72- b.
# 73- d.
# 74- d.
# 75- d.
# 76- a.
# 77- c.
# 78- d.
# 79- a.
# 80- a.
# 81- d.
# 82- b.
# 83- b.
# 84- a.
# 85- a.
# 86- a.
# 87- d.
# 88- d.
# 89- d.
# 90- d.
# 91- a.
# 92- b.
# 93- b.
# 94- b.
# 95- c.
# 96- c.
# 97- c.
# 98- c.
# 99- b.
# 100- a.
# 101- d.
# 102- b.
# 103- b.
# 104- a.
# 105- b.
# 106- b.
# 107- b.
# 108- d.
# 109- d.
# 110- b.
# ...

# %%
import re
import json
from IPython.display import HTML, display
from google.colab import files

# 1. الأسئلة (السؤال والاختيارات في سطر واحد أو سطرين)
raw_questions = """
1- the visibility is very bad here ; I can’t ….. Anything
a- warn. b- hear. c- see. d- reach.
2- they are listening to the ………..
a- radio. b- time. c- TV. d- map.
3- your TV is too………..
a- louder. b- loud. c- loudest. d- loudly.
4- she speaks very ………..
a- more quick. b- quickly. c- quicker. d- more quickly.
5- check your work………..
a- more careful. b- more carefulness. c- careful. d- carefully.
6- you should report to the army………... ASAP
a- headquarters. b- auditorium. c- piers. d- council.
7- Americans regard the half-dollar as a………..
a- treasure. b- bad omen. c- taboo. d- good luck.
8- A:"I really need to speak to you now. "B:"oh,all right if you……
a- complicate. b- resist. c- finalize. d- insist.
a- defective. b- informative. c- careful. d- fruitful.
79- An armored personnel carrier is considered a ………….
a- vehicle. b- tank. c- cannon. d- shield.
80- A: How do you ……………. These low test scores? B: I know the explanation
a- account for. b- think through. c- make up. d- get across.
81- The talk about the weather’s ………………….
a- severeness. b- severiting. c- severition. d- severity.
82- They fired him from job
a- engaged. b- discharged. c- employed. d- hired.
83- Mark is a very proficient worker
a- incompetent. b- skilled. c- bad. d- untrained.
84- The teacher gave me an assingnment
a- task. b- punishment. c- a speech. d- award.
85- They try to faster their relationships
a- enhance. b- cut. c- suspend. d- offend.
86- There is no point in asking Joe to pay for it ; he is a real tightwad
a- He is stingy. b- He is argumentative. c- He is ugly. d- He is silly.
87- The troops in the field need to take hot showers as soon as possible, we are concerned about their …
a- hyene. b- hyphen. c- hydraulics. d- hygiene.
88- After someone placed the picture on the Internet it was quickly disseminated around the world
a- exploited. b- vanished. c- deleted. d- spread.
89- Eventhough uncle Bill used to climb mountains , he is not as ……… as before
a- astringent. b- aged. c- antisocial. d- agile.
90- We are having inclement weather
a- dry. b- snowy. c- mild. d- stormy.
91- Rabbits ………………. To eat carrots
a- like. b- liking. c- likes. d- are like.
92- The heavy rain caused a lot of ……………….. In the valley
a- reflection. b- destruction. c- crops. d- location.
93- My sister …………… to her company everyday
a- walk. b- walks. c- is walk. d- walking.
94- Yesterday was ………………… than today
a- the most cold. b- colder. c- coldest. d- more cold.
95- A horse can run …………….. A cow
a- more faster than. b- more fastly than. c- faster than. d- as fast than.
96- A: You ought to study hard, our test is tomorrow. B: Yes, we ……
a- will. b- have to. c- should. d- must.
97- There was a crack in the front part of the airplane
a- rear. b- tail. c- cockpit. d- wing.
98- The price of cars, boats, furs, and other luxury items ……….. Rising
a- have been. b- are being. c- is. d- are.
99- My father was so angry with me that he ……….. The phone
a- hanged up. b- hung up. c- hang up. d- hanging up.
100- Students ……………. At the end of this year
a- are going to be examined. b- will examine. c- will be examining. d- are going to examine.
101- …………………, we could not have our picnic in the park
a- Because it raining. b- Because of raining. c- Since it was much raining. d- Since it was raining.
102- The ………………. Is a part of the car
a- Tool. b- Carburator. c- Thermostate. d- Barometer.
103- ……………. Is that room?
a- How long. b- what length. c- How length. d- What long.
104- Water …………….At100 degrees celsuis
a- boils. b- freeze. c- boil. d- freezes.
105- He should ………….. Pass the test
a- easy. b- easily. c- easier. d- ease.
106- CENTCOM is one of nine …………. Commands in the Department of Defense
a- activated. b- unified. c- provided. d- defined.
107- To load and board a ship is to "embark". To unload and get off aship is to …………
a- reload. b- debark. c- designate. d- refill.
108- To express your viewpoint in a discussion on a specific matter is to ……….. It
a- refuse. b- perform. c- suggest. d- confirm.
109- A Large farm, especially one of extensive land for cattle, is called a ……….
a- land. b- field. c- territory. d- ranch.
110- In the past, people worked and tilled with simple, crude, basic tools, Tools were ………
a- polished. b- primitive. c- sophisticated. d- advanced.
111- He can’t administrate the school
a- facilitate. b- reconstruct. c- manage. d- join.
112- The live in squalid conditions here
a- prosperity. b- wealthy. c- advance. d- misery.
467- d.
468- c.
469- c.
470- a.
471- b.
472- a.
473- d.
474- a.
475- a.
476- b.
477- b.
478- d.
479- b.
480- b.
481- d.
482- a.
483- b.
484- d.
485- c.
486- b.
487- d.
488- d.
489- a.
490- d.
491- b.
492- b.
493- a.
494- a.
495- a.
496- b.
497- b.
498- c.
499- a.
500- a.
501- a.
502- b.
503- c.
504- a.
505- d.
506- b.
507- c.
508- b.
509- a.
510- c.
511- d.
512- c.
513- a.
514- a.
515- b.
516- a.
517- a.
518- c.
519- a.
520- a.
521- a.
522- a.
523- b.
524- c.
525- a.
526- a.
527- b.
528- d.
529- a.
530- c.
531- b.
532- a.
533- a.
534- a.
535- d.
536- b.
537- d.
538- c.
539- d.
540- d.
541- b.
542- d.
543- a.
544- c.
545- a.
546- c.
547- c.
548- b.
549- a.
550- c.
551- a.
552- a.
553- c.
554- a.
555- d.
556- a.
557- c.
558- c.
559- d.
560- d.
561- d.
562- d.
563- d.
564- d.
565- a.
566- b.
567- b.
568- b.
569- d.
570- c.
571- b.
572- d.
573- a.
574- a.
575- a.
576- a.
577- b.
578- d.
579- b.
580- a.
581- b.
582- b.
583- b.
584- b.
585- b.
586- c.
587- d.
588- d.
589- a.
590- a.
591- c.
592- b.
593- c.
594- c.
595- b.
596- b.
597- b.
598- a.
599- d.
600- d.
601- a.
602- c.
603- d.
604- b.
605- b.
606- a.
607- b.
608- b.
609- a.
610- d.
611- d.
612- d.
613- d.
614- a.
615- a.
616- a.
617- a.
618- d.
619- d.
620- b.
621- d.
622- c.
623- d.
624- a.
625- a.
626- a.
627- d.
628- d.
629- b.
630- c.
631- c.
632- d.
633- c.
634- b.
635- a.
636- a.
637- c.
638- b.
639- b.
640- b.
641- a.
642- b.
643- a.
644- d.
645- b.
646- b.
647- d.
648- d.
649- b.
650- b.
651- a.
652- b.
653- d.
654- d.
655- b.
656- c.
657- c.
658- b.
659- c.
660- a.
661- a.
662- a.
663- c.
664- b.
665- a.
666- a.
667- b.
668- c.
669- c.
670- b.
671- b.
672- d.
673- b.
674- a.
675- b.
676- d.
677- d.
678- d.
679- c.
680- d.
681- b.
682- b.
683- c.
684- b.
685- d.
686- c.
687- c.
688- d.
689- c.
690- c.
691- d.
692- b.
693- b.
694- a.
695- d.
696- d.
697- c.
698- d.
699- a.
700- b.
"""
def parse_professional(q_text, a_text):
    questions_list = []
    ans_map = {}
    ans_matches = re.findall(r'(\d+)-\s*([a-dA-D])', a_text)
    for num, letter in ans_matches:
        ans_map[num] = ord(letter.lower()) - ord('a')

    q_parts = re.split(r'(\d+-\s)', q_text.strip())
    for i in range(1, len(q_parts), 2):
        q_num_str = q_parts[i].replace('-', '').strip()
        content = q_parts[i+1]
        parts = re.split(r'\s+([a-dA-D][-.)])\s+', content)
        main_question = parts[0].strip()
        options = [parts[j].strip() for j in range(2, len(parts), 2)]
        while len(options) < 4: options.append("-")
        questions_list.append({
            "num": q_num_str, "q": main_question, "opts": options[:4], "ans": ans_map.get(q_num_str, 0)
        })
    return json.dumps(questions_list, ensure_ascii=False)

json_data = parse_professional(raw_questions, raw_answers)

html_template = f"""
<!DOCTYPE html>
<html lang="ar" dir="rtl">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <style>
        :root {{ --primary: #2c3e50; --accent: #e67e22; --success: #27ae60; --bg: #f8f9fa; }}
        body {{ font-family: 'Segoe UI', sans-serif; background: var(--bg); display: flex; justify-content: center; padding: 10px; margin: 0; }}
        .quiz-card {{ background: white; width: 100%; max-width: 550px; padding: 25px; border-radius: 20px; box-shadow: 0 10px 30px rgba(0,0,0,0.1); }}
        .brand {{ text-align: center; font-size: 2.5rem; font-weight: 900; color: var(--accent); margin-bottom: 10px; letter-spacing: 5px; text-shadow: 2px 2px #eee; }}
        .q-text {{ font-size: 1.15rem; font-weight: 600; margin: 20px 0; text-align: left; direction: ltr; line-height: 1.6; color: #34495e; }}
        .option-btn {{ display: block; width: 100%; padding: 14px; margin: 10px 0; border: 2px solid #f0f0f0; border-radius: 12px; background: #fff; cursor: pointer; text-align: left; direction: ltr; transition: 0.2s; }}
        .option-btn.selected {{ border-color: var(--accent); background: #fff5eb; }}
        .show-ans-btn {{ background: #9b59b6; color: white; border: none; padding: 8px 15px; border-radius: 8px; cursor: pointer; font-size: 0.9rem; margin-top: 10px; }}
        .nav-section {{ display: flex; gap: 10px; margin-top: 25px; }}
        .btn {{ flex: 1; padding: 12px; border: none; border-radius: 10px; cursor: pointer; font-weight: bold; }}
        .btn-next {{ background: var(--primary); color: white; }}
        .correct-hint {{ color: var(--success); font-weight: bold; margin-top: 10px; text-align: left; direction: ltr; display: none; }}
        .result-screen {{ text-align: center; padding: 30px; }}
    </style>
</head>
<body>
<div class="quiz-card" id="quiz-ui">
    <div class="brand"> 700 question yehia </div>
    <div id="quiz-body">
        <div id="q-text" class="q-text"></div>
        <div id="options-area"></div>
        <button class="show-ans-btn" onclick="toggleAns()">Show Answer 👁️</button>
        <div id="ans-hint" class="correct-hint"></div>
        <div class="nav-section">
            <button class="btn" style="background:#bdc3c7" onclick="move(-1)">السابق</button>
            <button class="btn btn-next" id="next-text" onclick="move(1)">التالي</button>
        </div>
    </div>
</div>

<script>
    const data = {json_data};
    let idx = 0;
    let userSels = {{}};

    function render() {{
        if(idx >= data.length) {{
            showFinalResult();
            return;
        }}
        const item = data[idx];
        document.getElementById('q-text').innerText = item.num + "- " + item.q;
        document.getElementById('ans-hint').innerText = "Correct Answer: " + String.fromCharCode(97 + item.ans) + ") " + item.opts[item.ans];
        document.getElementById('ans-hint').style.display = "none";

        const area = document.getElementById('options-area');
        area.innerHTML = "";
        item.opts.forEach((o, i) => {{
            const b = document.createElement('button');
            b.className = 'option-btn' + (userSels[idx] === i ? ' selected' : '');
            b.innerText = String.fromCharCode(97+i) + "- " + o;
            b.onclick = () => {{ userSels[idx] = i; render(); }};
            area.appendChild(b);
        }});
        document.getElementById('next-text').innerText = (idx === data.length - 1) ? "إنهاء الاختبار" : "التالي";
    }}

    function toggleAns() {{
        const hint = document.getElementById('ans-hint');
        hint.style.display = (hint.style.display === "none") ? "block" : "none";
    }}

    function move(n) {{
        if (n === 1 && idx === data.length - 1) {{ showFinalResult(); return; }}
        idx = Math.max(0, Math.min(data.length - 1, idx + n));
        render();
    }}

    function showFinalResult() {{
        let score = 0;
        data.forEach((item, i) => {{ if(userSels[i] === item.ans) score++; }});
        document.getElementById('quiz-body').innerHTML = `
            <div class="result-screen">
                <h2>النتيجة النهائية</h2>
                <h1 style="color:var(--accent); font-size: 3rem;">${{score}} / ${{data.length}}</h1>
                <p>لقد أجبت على ${{Object.keys(userSels).length}} سؤال من أصل ${{data.length}}</p>
                <button class="btn btn-next" onclick="location.reload()">إعادة الاختبار</button>
            </div>`;
    }}

    render();
</script>
</body>
</html>
"""

display(HTML(html_template))
with open("yehia_quiz.html", "w", encoding="utf-8") as f:
    f.write(html_template)
files.download("yehia_quiz.html")
# Out:
# <!DOCTYPE html>
# <html lang="ar" dir="rtl">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         :root { --primary: #2c3e50; --accent: #e67e22; --success: #27ae60; --bg: #f8f9fa; }
#         body { font-family: 'Segoe UI', sans-serif; background: var(--bg); display: flex; justify-content: center; padding: 10px; margin: 0; }
#         .quiz-card { background: white; width: 100%; max-width: 550px; padding: 25px; border-radius: 20px; box-shadow: 0 10px 30px rgba(0,0,0,0.1); }
#         .brand { text-align: center; font-size: 2.5rem; font-weight: 900; color: var(--accent); margin-bottom: 10px; letter-spacing: 5px; text-shadow: 2px 2px #eee; }
#         .q-text { font-size: 1.15rem; font-weight: 600; margin: 20px 0; text-align: left; direction: ltr; line-height: 1.6; color: #34495e; }
# ...

# %% [markdown]
# # Project Overview: Automated PDF Quiz Extraction & Interactivity
#
# This document summarizes the technical process used to transform a static 700-question English Proficiency Test from PDF format into a fully interactive Offline Web Application (Quiz App).
#
# ## 🛠 Tools & Technologies Used
# *   **Google Colab:** Cloud-based Python environment for data processing.
# *   **Python Libraries:**
#     *   `pdfplumber`: For high-precision table and text extraction from PDF.
#     *   `re` (Regular Expressions): For pattern matching, text cleaning, and formatting.
#     *   `json`: To structure the data for web compatibility.
# *   **Web Technologies:** HTML5, CSS3 (Modern UI/UX), and Vanilla JavaScript for interactivity.
#
# ## 🚀 Execution Steps
#
# ### 1. Data Extraction & Cleaning
# We implemented custom Python scripts to parse the PDF. The challenge was splitting long questions and multiple-choice options into distinct lines. We successfully formatted the raw data into:
# *   **Questions:** `[Number]- [Question Text]` followed by `a- [Option A] b- [Option B] ...`
# *   **Answers:** A clean vertical key formatted as `[Number]- [Letter].`
#
# ### 2. Regex Transformation
# Using advanced Regular Expressions, we ensured that:
# *   Every question is contained in a single line regardless of its original PDF layout.
# *   Choice markers were standardized from `a.` to `a-` and ended with a period `.` for consistency.
#
# ### 3. Data Integration
# The extracted text files were converted into a **JSON-like object**. This allowed us to map each question number to its corresponding correct answer automatically.
#
# ### 4. Interactive Product Development
# We built a standalone **HTML5 Offline Application** that features:
# *   **Dynamic Navigation:** Seamlessly move between 700 questions.
# *   **Instant Feedback:** A "Show Answer" toggle for study mode.
# *   **Score Calculation:** A final result screen to track performance.
# *   **Responsive Design:** Optimized for both Desktop and Mobile devices.
#
# ## 📦 Final Product
# The end result is **`yehia_quiz.html`**, a lightweight, portable, and professional interactive quiz tool that requires no internet connection to function.
